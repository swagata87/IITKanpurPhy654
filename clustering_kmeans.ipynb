# %% [markdown]
# <a href="https://colab.research.google.com/github/swagata87/IITKanpurPhy654/blob/main/clustering_kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 4, 4, 5, 5, 10, 4, 3, 11, 14 , 6, 10, 12, 14, 13, 11, 12, 12, 12]
y = [17, 17, 18, 21, 18, 19, 24, 17, 16, 25, 24, 22, 21, 21, 22, 24, 21, 24, 21, 22]

plt.scatter(x, y)
plt.show()

# %%
from sklearn.cluster import KMeans
data = list(zip(x, y))

# %%
print (data)
# Out:
# [(1, 17), (2, 17), (4, 18), (4, 21), (5, 18), (5, 19), (10, 24), (4, 17), (3, 16), (11, 25), (14, 24), (6, 22), (10, 21), (12, 21), (14, 22), (13, 24), (11, 21), (12, 24), (12, 21), (12, 22)]

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(data)

plt.scatter(x, y, c=kmeans.labels_)
plt.show()

# %%
# READ MORE HERE
# https://scikit-learn.org/1.5/modules/generated/sklearn.cluster.KMeans.html
